# %%
import pandas as pd

# %%
df = pd.read_csv('StockData/Stocks/aapl.us.txt', sep=",", header=None)

# %%
df
# Out:
#                0        1        2        3        4         5        6
# 0           Date     Open     High      Low    Close    Volume  OpenInt
# 1     1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030        0
# 2     1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532        0
# 3     1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199        0
# 4     1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801        0
# ...          ...      ...      ...      ...      ...       ...      ...
# 8360  2017-11-06   171.75   174.36    171.1   173.63  34901241        0
# 8361  2017-11-07   173.29   174.51   173.29   174.18  24424877        0
# 8362  2017-11-08   174.03   175.61   173.71   175.61  24451166        0
# 8363  2017-11-09   174.48   175.46   172.52   175.25  29533086        0
# 8364  2017-11-10   175.11   175.38   174.27   174.67  25130494        0
#
# [8365 rows x 7 columns]

# %%
# Remove the first row

# %%
df = df.iloc[1:]

# %%
df
# Out:
#                0        1        2        3        4         5  6
# 1     1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030  0
# 2     1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532  0
# 3     1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199  0
# 4     1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801  0
# 5     1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062  0
# ...          ...      ...      ...      ...      ...       ... ..
# 8360  2017-11-06   171.75   174.36    171.1   173.63  34901241  0
# 8361  2017-11-07   173.29   174.51   173.29   174.18  24424877  0
# 8362  2017-11-08   174.03   175.61   173.71   175.61  24451166  0
# 8363  2017-11-09   174.48   175.46   172.52   175.25  29533086  0
# 8364  2017-11-10   175.11   175.38   174.27   174.67  25130494  0
#
# [8364 rows x 7 columns]

# %%
# Name the columns

# %%
df.columns = ["Date", "Open", "High", "Low", "Close", "Volume", "OpenInt"]

# %%
df
# Out:
#             Date     Open     High      Low    Close    Volume OpenInt
# 1     1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030       0
# 2     1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532       0
# 3     1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199       0
# 4     1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801       0
# 5     1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062       0
# ...          ...      ...      ...      ...      ...       ...     ...
# 8360  2017-11-06   171.75   174.36    171.1   173.63  34901241       0
# 8361  2017-11-07   173.29   174.51   173.29   174.18  24424877       0
# 8362  2017-11-08   174.03   175.61   173.71   175.61  24451166       0
# 8363  2017-11-09   174.48   175.46   172.52   175.25  29533086       0
# 8364  2017-11-10   175.11   175.38   174.27   174.67  25130494       0
#
# [8364 rows x 7 columns]

# %%
# Remove the last column

# %% [markdown]
# <!-- Remove the last column -->

# %%
df = df.iloc[:,:-1]

# %%
df
# Out:
#             Date     Open     High      Low    Close    Volume
# 1     1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030
# 2     1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532
# 3     1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199
# 4     1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801
# 5     1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062
# ...          ...      ...      ...      ...      ...       ...
# 8360  2017-11-06   171.75   174.36    171.1   173.63  34901241
# 8361  2017-11-07   173.29   174.51   173.29   174.18  24424877
# 8362  2017-11-08   174.03   175.61   173.71   175.61  24451166
# 8363  2017-11-09   174.48   175.46   172.52   175.25  29533086
# 8364  2017-11-10   175.11   175.38   174.27   174.67  25130494
#
# [8364 rows x 6 columns]

# %%
df.head()
# Out:
#                Open     High      Low    Close    Volume
# Date
# 1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030
# 1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532
# 1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199
# 1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801
# 1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062

# %%
# df.set_index("Date", inplace=True)
# Trying to set "Date" as the index

# %%
recent_df = df.loc['2010-01-01':'2017-01-01']

# %%
recent_df
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2010-01-04  27.341   27.47  27.199  27.406  137045797
# 2010-01-05  27.508  27.609   27.31  27.454  167718021
# 2010-01-06  27.454  27.563   26.99  27.017  153403690
# 2010-01-07  27.108  27.148  26.772  26.968  132861904
# 2010-01-08  26.946  27.148  26.774  27.147  124730848
# ...            ...     ...     ...     ...        ...
# 2016-12-23  113.76  114.68  113.76  114.68   13998412
# 2016-12-27  114.68  115.93  114.65  115.41   17786684
# 2016-12-28  115.65  116.15  114.36  114.92   19619378
# 2016-12-29  114.61  115.26  114.56  114.89   14988280
# 2016-12-30  114.81  115.35   113.6  113.99   31078121
#
# [1762 rows x 5 columns]

# %%
recent_df.dtypes
# Type objects
# Out:
# Open      object
# High      object
# Low       object
# Close     object
# Volume    object
# dtype: object

# %%
# Convert to floats
recent_df['Open'] = recent_df['Open'].astype(float)
recent_df['High'] = recent_df['High'].astype(float)
recent_df['Low'] = recent_df['Low'].astype(float)
recent_df['Close'] = recent_df['Close'].astype(float)
recent_df['Volume'] = recent_df['Volume'].astype(float)
# Out:
# /var/folders/8f/ym98g4c11dq31vdqv1xl8glh0000gn/T/ipykernel_14409/1368761960.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_df['Open'] = recent_df['Open'].astype(float)
# /var/folders/8f/ym98g4c11dq31vdqv1xl8glh0000gn/T/ipykernel_14409/1368761960.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_df['High'] = recent_df['High'].astype(float)
# /var/folders/8f/ym98g4c11dq31vdqv1xl8glh0000gn/T/ipykernel_14409/1368761960.py:4: SettingWithCopyWarning:
# ...

# %%
recent_df.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
recent_df['Close'].plot()
# Closing prices from 2010 to 2016
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
recent_df['Volume'].plot()
# Trading volume from 2010 to 2016
# Out:
# <AxesSubplot:xlabel='Date'>
